# %%
import os
from cluster_bins_pcf import cluster_bins

seg=cluster_bins("example.fx")
# Out:
# [array([[0.41314554],
#        [0.1518796 ],
#        [0.43342776],
#        [0.14978863],
#        [0.44008959],
#        [0.30714675],
#        [0.44475292],
#        [0.39120589],
#        [0.45024739],
#        [0.28459851],
#        [0.43374858],
#        [0.24878993],
#        [0.45504087],
#        [0.43346878],
#        [0.498998  ],
#        [0.98486644],
#        [0.48849105],
#        [0.62676651],
#        [0.42922374],
#        [0.32601268],
#        [0.43246311],
#        [0.15464156],
#        [0.43534726],
#        [0.37945481],
#        [0.44598338],
#        [0.2220567 ],
#        [0.41451991],
#        [0.33797771],
#        [0.43374858],
#        [0.33102223],
#        [0.44196429],
#        [0.27990322],
#        [0.41961695],
#        [0.45977502],
#        [0.37264743],
#        [0.42750109],
#        [0.49469429],
#        [0.87055056],
#        [0.46323135],
#        [0.50382688],
#        [0.3964997 ],
#        [0.40584479],
#        [0.41758882],
# ...
